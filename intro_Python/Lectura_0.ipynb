# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# !pip install Unidecode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 8.7 MB/s eta 0:00:00
# ...

# %%
"ANA BELTRAN".lower()
# Out:
# 'ana beltran'

# %%
import pandas as pd

pd.DataFrame(
    {"col_1": [number for number in range(50, 60)]}
)
# Out:
#    col_1
# 0     50
# 1     51
# 2     52
# 3     53
# 4     54
# 5     55
# 6     56
# 7     57
# 8     58
# 9     59

# %%
from unidecode import unidecode

# %%
unidecode("Aná beltrán ojó con eso cositó")
# Out:
# 'Ana beltran ojo con eso cosito'

# %% [markdown]
# # En la anterior usamos la librería _unidecode_ para eliminar la tildes.
#
# 1.   Elemento 1 de la lista
# 2.   Elemento 2 de la lista
#
# $$\frac{4}{5}$$
#
# Visite la página oficial de python dando click [aquí](https://www.python.org/)

# %% [markdown]
# ```python
# from unidecode import unidecode
# unidecode("Aná beltrán ojó con eso cositó")
# ```

# %%
from unidecode import unidecode
unidecode("Aná beltrán ojó con eso cositó")
# Out:
# 'Ana beltran ojo con eso cosito'
